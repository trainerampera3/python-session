# %%
# Print statements and data types 
print("hello world")
name = "Vinay"    
age = 22         
height = 5.8      
company = "Ampera"
print("My name is",name,"," "i am",age ,"yeas old. My height is",height,"and i am working in",company,"company")
# Out:
# hello world
# My name is Vinay ,i am 22 yeas old. My height is 5.8 and i am working in Ampera company

# %%
# Dynmic input method
name = input("Enter name:")
print(name)
# Out:
# Enter name: vinay
# vinay

# %%
# Conditional statements
age = 20
if age >= 18:
    print("Eligible to Vote")
else:
    print("Not elegible to vote")
# Out:
# Eligible to Vote

# %%
# Loops
print("For loop iteration")
for i in range(5):
    print(i)

print("While loop iteration")
i = 1

while i <= 5:
    print(i)
    i += 1
# Out:
# For loop iteration
# 0
# 1
# 2
# 3
# 4
# While loop iteration
# 1
# 2
# 3
# 4
# 5

# %%
# Function sysntax
def greet(name):
    print("Hello", name)

greet("Vinay")
# Out:
# Hello Vinay

# %%
#  list ,Tuple, and diction
fruits = ["Apple", "Orange", "Banana"]
print(fruits[0])

my_tuple = (10, 20, 30)
print(my_tuple[0])

student = {
    "name": "Vinay",
    "age": 22
}
print(student["name"])
# Out:
# Apple
# 10
# Vinay

# %%
import math

print(math.sqrt(25))
# Out:
# 5.0
