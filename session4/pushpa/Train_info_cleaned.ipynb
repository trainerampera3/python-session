# %%
import pandas as pd
schedule = pd.read_csv("train_schedule.csv")
train_info = pd.read_csv("train_info.csv")
schedule.shape
# train_info.shape
# Out:
# (186074, 12)

# %%
train_info.shape
# Out:
# (11113, 5)

# %%
train_info.info
train_info
# Out:
#        Train_No    Train_Name Source_Station_Name  \
# 0           107  SWV-MAO-VLNK     SAWANTWADI ROAD
# 1           108  VLNK-MAO-SWV         MADGOAN JN.
# 2           128  MAO-KOP SPEC         MADGOAN JN.
# 3           290  PALACE ON WH   DELHI-SAFDAR JANG
# 4           401  BSB BHARATDA          AURANGABAD
# ...         ...           ...                 ...
# 11108     99904  PUNE-TGN EMU            PUNE JN.
# 11109     99905           EMU            TALEGAON
# 11110     99906           EMU            PUNE JN.
# 11111     99907           EMU            TALEGAON
# 11112     99908           EMU            PUNE JN.
#
#                  Destination_Station_Name       days
# 0                             MADGOAN JN.   Saturday
# 1                         SAWANTWADI ROAD     Friday
# 2      CHHATRAPATI SHAHU MAHARAJ TERMINUS     Friday
# 3                       DELHI-SAFDAR JANG  Wednesday
# 4                            VARANASI JN.   Saturday
# ...

# %%
schedule.info()
schedule
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186074 entries, 0 to 186073
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   SN              186074 non-null  int64
#  1   Train_No        186074 non-null  int64
#  2   Station_Code    186074 non-null  object
#  3   1A              186074 non-null  int64
#  4   2A              186074 non-null  int64
#  5   3A              186074 non-null  int64
#  6   SL              186074 non-null  int64
#  7   Station_Name    186064 non-null  object
#  8   Route_Number    186074 non-null  int64
#  9   Arrival_time    186064 non-null  object
#  10  Departure_Time  186074 non-null  object
#  11  Distance        186064 non-null  float64
# dtypes: float64(1), int64(7), object(4)
# memory usage: 17.0+ MB
#         SN  Train_No Station_Code    1A    2A    3A    SL     Station_Name  \
# 0        1       107          SWV   100   100   100   100     SAWANTWADI R
# ...

# %%
schedule.describe(include="all")
# Out:
#                    SN       Train_No Station_Code             1A  \
# count   186074.000000  186074.000000       186074  186074.000000
# unique            NaN            NaN         8147            NaN
# top               NaN            NaN         CSMT            NaN
# freq              NaN            NaN         1027            NaN
# mean        13.914695   42157.747455          NaN    1506.769189
# std         12.779368   25090.080221          NaN    2418.719821
# min          1.000000     107.000000          NaN     100.000000
# 25%          5.000000   17225.000000          NaN     215.000000
# 50%         11.000000   40050.000000          NaN     465.000000
# 75%         18.000000   57550.000000          NaN    1555.000000
# max        118.000000   99908.000000          NaN   21400.000000
#
#                    2A             3A             SL Station_Name  \
# count   186074.000000  186074.000000  186074.000000       186064
# ...

# %%
train_info.describe(include="all")
# Out:
#             Train_No   Train_Name Source_Station_Name  \
# count   11113.000000        11103               11103
# unique           NaN         7575                 921
# top              NaN  TBM-MSB EMU          CST-MUMBAI
# freq             NaN          139                 513
# mean    49190.570413          NaN                 NaN
# std     28515.986645          NaN                 NaN
# min       107.000000          NaN                 NaN
# 25%     22607.000000          NaN                 NaN
# 50%     47174.000000          NaN                 NaN
# 75%     68012.000000          NaN                 NaN
# max     99908.000000          NaN                 NaN
#
#        Destination_Station_Name    days
# count                     11113   11103
# unique                      924      14
# top                  CST-MUMBAI  Friday
# freq                        514    1471
# mean                        NaN     NaN
# std                         NaN     NaN
# ...

# %%
schedule.isnull().sum()
# Out:
# SN                 0
# Train_No           0
# Station_Code       0
# 1A                 0
# 2A                 0
# 3A                 0
# SL                 0
# Station_Name      10
# Route_Number       0
# Arrival_time      10
# Departure_Time     0
# Distance          10
# dtype: int64

# %%
train_info.isnull().sum()
# Out:
# Train_No                     0
# Train_Name                  10
# Source_Station_Name         10
# Destination_Station_Name     0
# days                        10
# dtype: int64

# %%
(schedule.isnull().sum() / len(schedule) * 100).sort_values(ascending=False)
# Out:
# Station_Name      0.005374
# Arrival_time      0.005374
# Distance          0.005374
# SN                0.000000
# Train_No          0.000000
# Station_Code      0.000000
# 1A                0.000000
# 2A                0.000000
# 3A                0.000000
# SL                0.000000
# Route_Number      0.000000
# Departure_Time    0.000000
# dtype: float64

# %%
(train_info.isnull().sum() / len(train_info) * 100).sort_values(ascending=False)
# Out:
# Train_Name                  0.089985
# Source_Station_Name         0.089985
# days                        0.089985
# Train_No                    0.000000
# Destination_Station_Name    0.000000
# dtype: float64

# %%
schedule.duplicated().sum()
# Out:
# 0

# %%
train_info.duplicated().sum()
# Out:
# 0

# %%
schedule = schedule.drop_duplicates()
schedule
# Out:
#         SN  Train_No Station_Code    1A    2A    3A    SL     Station_Name  \
# 0        1       107          SWV   100   100   100   100     SAWANTWADI R
# 1        2       107         THVM   260   228   196   164           THIVIM
# 2        3       107         KRMI   345   296   247   198          KARMALI
# 3        4       107          MAO   490   412   334   256      MADGOAN JN.
# 4        1       108          MAO   100   100   100   100      MADGOAN JN.
# ...     ..       ...          ...   ...   ...   ...   ...              ...
# 186069   1     22439         NDLS   100   100   100   100        NEW DELHI
# 186070   2     22439          UMB  1095   896   697  1095   AMBALA CANT JN
# 186071   3     22439          LDH  1660  1348  1036  1660      LUDHIANA JN
# 186072   4     22439          JAT  2985  2408  1831  2985       JAMMU TAWI
# 186073   5     22439         SVDK  3375  2720  2065  3375  SHMATA VD KATRA
#
#         Route_Number Arrival_time Departure_Time  Distance
# ...

# %%
train_info = train_info.drop_duplicates()
train_info
# Out:
#        Train_No    Train_Name Source_Station_Name  \
# 0           107  SWV-MAO-VLNK     SAWANTWADI ROAD
# 1           108  VLNK-MAO-SWV         MADGOAN JN.
# 2           128  MAO-KOP SPEC         MADGOAN JN.
# 3           290  PALACE ON WH   DELHI-SAFDAR JANG
# 4           401  BSB BHARATDA          AURANGABAD
# ...         ...           ...                 ...
# 11108     99904  PUNE-TGN EMU            PUNE JN.
# 11109     99905           EMU            TALEGAON
# 11110     99906           EMU            PUNE JN.
# 11111     99907           EMU            TALEGAON
# 11112     99908           EMU            PUNE JN.
#
#                  Destination_Station_Name       days
# 0                             MADGOAN JN.   Saturday
# 1                         SAWANTWADI ROAD     Friday
# 2      CHHATRAPATI SHAHU MAHARAJ TERMINUS     Friday
# 3                       DELHI-SAFDAR JANG  Wednesday
# 4                            VARANASI JN.   Saturday
# ...

# %%
schedule.columns = schedule.columns.str.strip()
schedule
# Out:
#         SN  Train_No Station_Code    1A    2A    3A    SL     Station_Name  \
# 0        1       107          SWV   100   100   100   100     SAWANTWADI R
# 1        2       107         THVM   260   228   196   164           THIVIM
# 2        3       107         KRMI   345   296   247   198          KARMALI
# 3        4       107          MAO   490   412   334   256      MADGOAN JN.
# 4        1       108          MAO   100   100   100   100      MADGOAN JN.
# ...     ..       ...          ...   ...   ...   ...   ...              ...
# 186069   1     22439         NDLS   100   100   100   100        NEW DELHI
# 186070   2     22439          UMB  1095   896   697  1095   AMBALA CANT JN
# 186071   3     22439          LDH  1660  1348  1036  1660      LUDHIANA JN
# 186072   4     22439          JAT  2985  2408  1831  2985       JAMMU TAWI
# 186073   5     22439         SVDK  3375  2720  2065  3375  SHMATA VD KATRA
#
#         Route_Number Arrival_time Departure_Time  Distance
# ...

# %%
train_info.columns = train_info.columns.str.strip()
train_info
# Out:
#        Train_No    Train_Name Source_Station_Name  \
# 0           107  SWV-MAO-VLNK     SAWANTWADI ROAD
# 1           108  VLNK-MAO-SWV         MADGOAN JN.
# 2           128  MAO-KOP SPEC         MADGOAN JN.
# 3           290  PALACE ON WH   DELHI-SAFDAR JANG
# 4           401  BSB BHARATDA          AURANGABAD
# ...         ...           ...                 ...
# 11108     99904  PUNE-TGN EMU            PUNE JN.
# 11109     99905           EMU            TALEGAON
# 11110     99906           EMU            PUNE JN.
# 11111     99907           EMU            TALEGAON
# 11112     99908           EMU            PUNE JN.
#
#                  Destination_Station_Name       days
# 0                             MADGOAN JN.   Saturday
# 1                         SAWANTWADI ROAD     Friday
# 2      CHHATRAPATI SHAHU MAHARAJ TERMINUS     Friday
# 3                       DELHI-SAFDAR JANG  Wednesday
# 4                            VARANASI JN.   Saturday
# ...

# %%
schedule[schedule.isnull().any(axis=1)]
# Out:
#        SN  Train_No Station_Code     1A    2A    3A    SL  Station_Name  \
# 1000   11      4831          CUR   1820  1476  1132   788           NaN
# 1100   13      4921          UMB    505   424   343   262  AMBALA CANTT
# 5000   26     11021           TK   5795  4656  3517  2378           NaN
# 5100   19     11024         SVJR   1740  1412  1084   756  SHIVAJINAGAR
# 10000  24     12146           NK   8720  6996  5272  3548           NaN
# 10100  15     12151          JSG   7305  5864  4423  2982  JHARSUGUDA J
# 15000  20     12486           ET   6355  5104  3853  2602           NaN
# 15100  11     12491          SCC   3625  2920  2215  1510  SITAPUR CANT
# 20000   6     12762          KMT   1225  1000   775   550           NaN
# 20100   8     12767         MJRI   1520  1236   952   668     MAJRI JN.
# 25000   2     13019          SRP    195   176   157   138           NaN
# 25100  36     13020          HJP   4625  3720  2815  1910   HAJIPUR JN.
# ...

# %%
schedule = schedule.dropna(
    subset=["Station_Name", "Arrival_time", "Distance"]
)
schedule
# Out:
#         SN  Train_No Station_Code    1A    2A    3A    SL     Station_Name  \
# 0        1       107          SWV   100   100   100   100     SAWANTWADI R
# 1        2       107         THVM   260   228   196   164           THIVIM
# 2        3       107         KRMI   345   296   247   198          KARMALI
# 3        4       107          MAO   490   412   334   256      MADGOAN JN.
# 4        1       108          MAO   100   100   100   100      MADGOAN JN.
# ...     ..       ...          ...   ...   ...   ...   ...              ...
# 186069   1     22439         NDLS   100   100   100   100        NEW DELHI
# 186070   2     22439          UMB  1095   896   697  1095   AMBALA CANT JN
# 186071   3     22439          LDH  1660  1348  1036  1660      LUDHIANA JN
# 186072   4     22439          JAT  2985  2408  1831  2985       JAMMU TAWI
# 186073   5     22439         SVDK  3375  2720  2065  3375  SHMATA VD KATRA
#
#         Route_Number Arrival_time Departure_Time  Distance
# ...

# %%
train_info[train_info.isnull().any(axis=1)]
train_info
# Out:
#        Train_No    Train_Name Source_Station_Name  \
# 0           107  SWV-MAO-VLNK     SAWANTWADI ROAD
# 1           108  VLNK-MAO-SWV         MADGOAN JN.
# 2           128  MAO-KOP SPEC         MADGOAN JN.
# 3           290  PALACE ON WH   DELHI-SAFDAR JANG
# 4           401  BSB BHARATDA          AURANGABAD
# ...         ...           ...                 ...
# 11108     99904  PUNE-TGN EMU            PUNE JN.
# 11109     99905           EMU            TALEGAON
# 11110     99906           EMU            PUNE JN.
# 11111     99907           EMU            TALEGAON
# 11112     99908           EMU            PUNE JN.
#
#                  Destination_Station_Name       days
# 0                             MADGOAN JN.   Saturday
# 1                         SAWANTWADI ROAD     Friday
# 2      CHHATRAPATI SHAHU MAHARAJ TERMINUS     Friday
# 3                       DELHI-SAFDAR JANG  Wednesday
# 4                            VARANASI JN.   Saturday
# ...

# %%
schedule = schedule.dropna(
    subset=["Station_Name", "Arrival_time", "Distance"]
)
schedule
# Out:
#         SN  Train_No Station_Code    1A    2A    3A    SL     Station_Name  \
# 0        1       107          SWV   100   100   100   100     SAWANTWADI R
# 1        2       107         THVM   260   228   196   164           THIVIM
# 2        3       107         KRMI   345   296   247   198          KARMALI
# 3        4       107          MAO   490   412   334   256      MADGOAN JN.
# 4        1       108          MAO   100   100   100   100      MADGOAN JN.
# ...     ..       ...          ...   ...   ...   ...   ...              ...
# 186069   1     22439         NDLS   100   100   100   100        NEW DELHI
# 186070   2     22439          UMB  1095   896   697  1095   AMBALA CANT JN
# 186071   3     22439          LDH  1660  1348  1036  1660      LUDHIANA JN
# 186072   4     22439          JAT  2985  2408  1831  2985       JAMMU TAWI
# 186073   5     22439         SVDK  3375  2720  2065  3375  SHMATA VD KATRA
#
#         Route_Number Arrival_time Departure_Time  Distance
# ...

# %%
schedule["Arrival_time"] = pd.to_datetime(
    schedule["Arrival_time"],
    format="%H:%M:%S"
)

schedule["Departure_Time"] = pd.to_datetime(
    schedule["Departure_Time"],
    format="%H:%M:%S"
)
schedule
# Out:
#         SN  Train_No Station_Code    1A    2A    3A    SL     Station_Name  \
# 0        1       107          SWV   100   100   100   100     SAWANTWADI R
# 1        2       107         THVM   260   228   196   164           THIVIM
# 2        3       107         KRMI   345   296   247   198          KARMALI
# 3        4       107          MAO   490   412   334   256      MADGOAN JN.
# 4        1       108          MAO   100   100   100   100      MADGOAN JN.
# ...     ..       ...          ...   ...   ...   ...   ...              ...
# 186069   1     22439         NDLS   100   100   100   100        NEW DELHI
# 186070   2     22439          UMB  1095   896   697  1095   AMBALA CANT JN
# 186071   3     22439          LDH  1660  1348  1036  1660      LUDHIANA JN
# 186072   4     22439          JAT  2985  2408  1831  2985       JAMMU TAWI
# 186073   5     22439         SVDK  3375  2720  2065  3375  SHMATA VD KATRA
#
# ...

# %%
schedule["Train_No"].nunique()
schedule
# Out:
#         SN  Train_No Station_Code    1A    2A    3A    SL     Station_Name  \
# 0        1       107          SWV   100   100   100   100     SAWANTWADI R
# 1        2       107         THVM   260   228   196   164           THIVIM
# 2        3       107         KRMI   345   296   247   198          KARMALI
# 3        4       107          MAO   490   412   334   256      MADGOAN JN.
# 4        1       108          MAO   100   100   100   100      MADGOAN JN.
# ...     ..       ...          ...   ...   ...   ...   ...              ...
# 186069   1     22439         NDLS   100   100   100   100        NEW DELHI
# 186070   2     22439          UMB  1095   896   697  1095   AMBALA CANT JN
# 186071   3     22439          LDH  1660  1348  1036  1660      LUDHIANA JN
# 186072   4     22439          JAT  2985  2408  1831  2985       JAMMU TAWI
# 186073   5     22439         SVDK  3375  2720  2065  3375  SHMATA VD KATRA
#
# ...

# %%
train_info["Train_No"].nunique()
train_info
# Out:
#        Train_No    Train_Name Source_Station_Name  \
# 0           107  SWV-MAO-VLNK     SAWANTWADI ROAD
# 1           108  VLNK-MAO-SWV         MADGOAN JN.
# 2           128  MAO-KOP SPEC         MADGOAN JN.
# 3           290  PALACE ON WH   DELHI-SAFDAR JANG
# 4           401  BSB BHARATDA          AURANGABAD
# ...         ...           ...                 ...
# 11108     99904  PUNE-TGN EMU            PUNE JN.
# 11109     99905           EMU            TALEGAON
# 11110     99906           EMU            PUNE JN.
# 11111     99907           EMU            TALEGAON
# 11112     99908           EMU            PUNE JN.
#
#                  Destination_Station_Name       days
# 0                             MADGOAN JN.   Saturday
# 1                         SAWANTWADI ROAD     Friday
# 2      CHHATRAPATI SHAHU MAHARAJ TERMINUS     Friday
# 3                       DELHI-SAFDAR JANG  Wednesday
# 4                            VARANASI JN.   Saturday
# ...

# %%
train_info["days"].value_counts()
train_info
# Out:
#        Train_No    Train_Name Source_Station_Name  \
# 0           107  SWV-MAO-VLNK     SAWANTWADI ROAD
# 1           108  VLNK-MAO-SWV         MADGOAN JN.
# 2           128  MAO-KOP SPEC         MADGOAN JN.
# 3           290  PALACE ON WH   DELHI-SAFDAR JANG
# 4           401  BSB BHARATDA          AURANGABAD
# ...         ...           ...                 ...
# 11108     99904  PUNE-TGN EMU            PUNE JN.
# 11109     99905           EMU            TALEGAON
# 11110     99906           EMU            PUNE JN.
# 11111     99907           EMU            TALEGAON
# 11112     99908           EMU            PUNE JN.
#
#                  Destination_Station_Name       days
# 0                             MADGOAN JN.   Saturday
# 1                         SAWANTWADI ROAD     Friday
# 2      CHHATRAPATI SHAHU MAHARAJ TERMINUS     Friday
# 3                       DELHI-SAFDAR JANG  Wednesday
# 4                            VARANASI JN.   Saturday
# ...

# %%
schedule[["1A", "2A", "3A", "SL"]].describe()
schedule
# Out:
#         SN  Train_No Station_Code    1A    2A    3A    SL     Station_Name  \
# 0        1       107          SWV   100   100   100   100     SAWANTWADI R
# 1        2       107         THVM   260   228   196   164           THIVIM
# 2        3       107         KRMI   345   296   247   198          KARMALI
# 3        4       107          MAO   490   412   334   256      MADGOAN JN.
# 4        1       108          MAO   100   100   100   100      MADGOAN JN.
# ...     ..       ...          ...   ...   ...   ...   ...              ...
# 186069   1     22439         NDLS   100   100   100   100        NEW DELHI
# 186070   2     22439          UMB  1095   896   697  1095   AMBALA CANT JN
# 186071   3     22439          LDH  1660  1348  1036  1660      LUDHIANA JN
# 186072   4     22439          JAT  2985  2408  1831  2985       JAMMU TAWI
# 186073   5     22439         SVDK  3375  2720  2065  3375  SHMATA VD KATRA
#
# ...

# %%
merged_data = schedule.merge(
    train_info,
    on="Train_No",
    how="left"
)
schedule
# Out:
#         SN  Train_No Station_Code    1A    2A    3A    SL     Station_Name  \
# 0        1       107          SWV   100   100   100   100     SAWANTWADI R
# 1        2       107         THVM   260   228   196   164           THIVIM
# 2        3       107         KRMI   345   296   247   198          KARMALI
# 3        4       107          MAO   490   412   334   256      MADGOAN JN.
# 4        1       108          MAO   100   100   100   100      MADGOAN JN.
# ...     ..       ...          ...   ...   ...   ...   ...              ...
# 186069   1     22439         NDLS   100   100   100   100        NEW DELHI
# 186070   2     22439          UMB  1095   896   697  1095   AMBALA CANT JN
# 186071   3     22439          LDH  1660  1348  1036  1660      LUDHIANA JN
# 186072   4     22439          JAT  2985  2408  1831  2985       JAMMU TAWI
# 186073   5     22439         SVDK  3375  2720  2065  3375  SHMATA VD KATRA
#
# ...
