# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("ecommerce_sales_analytics_5000.csv")
df
# Out:
#       order_id order_date  customer_id product_category region  quantity  \
# 0        10001   1/1/2022         1102           Beauty  South         7
# 1        10002   1/2/2022         1435         Clothing  South         7
# 2        10003   1/3/2022         1860           Beauty   East         3
# 3        10004   1/4/2022         1270      Electronics   West         5
# 4        10005   1/5/2022         1106         Clothing   West         5
# ...        ...        ...          ...              ...    ...       ...
# 4995     14996   9/5/2035         1289         Clothing   West         2
# 4996     14997   9/6/2035         1294           Beauty  North         3
# 4997     14998   9/7/2035         1450           Beauty   West         3
# 4998     14999   9/8/2035         1903      Electronics  South         4
# 4999     15000   9/9/2035         1214             Home   East         7
#
#       unit_price  discount payment_method  delivery_days  customer_rating  \
# 0         373.65      0.28         Wallet             10              4.7
# 1          47.74      0.09           Card              6              3.9
# 2         311.28      0.31            COD              6              2.5
# 3         524.47      0.02         Wallet              6              1.6
# 4         139.87      0.33         Wallet              4              4.9
# ...          ...       ...            ...            ...              ...
# 4995      371.74      0.27            COD              3              2.3
# 4996      553.67      0.14            COD             11              2.2
# 4997       77.22      0.24         Wallet              6              3.4
# 4998      138.41      0.21            COD              4              2.8
# 4999      231.58      0.34            COD              5              3.9
#
#       revenue
# 0     1883.20
# 1      304.10
# 2      644.35
# 3     2569.90
# 4      468.56
# ...       ...
# 4995   542.74
# 4996  1428.47
# 4997   176.06
# 4998   437.38
# 4999  1069.90
#
# [5000 rows x 12 columns]

# %%
df.head()
# Out:
#    order_id order_date  customer_id product_category region  quantity  \
# 0     10001   1/1/2022         1102           Beauty  South         7
# 1     10002   1/2/2022         1435         Clothing  South         7
# 2     10003   1/3/2022         1860           Beauty   East         3
# 3     10004   1/4/2022         1270      Electronics   West         5
# 4     10005   1/5/2022         1106         Clothing   West         5
#
#    unit_price  discount payment_method  delivery_days  customer_rating  \
# 0      373.65      0.28         Wallet             10              4.7
# 1       47.74      0.09           Card              6              3.9
# 2      311.28      0.31            COD              6              2.5
# 3      524.47      0.02         Wallet              6              1.6
# 4      139.87      0.33         Wallet              4              4.9
#
#    revenue
# 0  1883.20
# 1   304.10
# 2   644.35
# 3  2569.90
# 4   468.56

# %%
df.describe()
# Out:
#            order_id  customer_id     quantity   unit_price     discount  \
# count   5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean   12500.500000  1505.701200     4.044800   308.418774     0.179984
# std     1443.520003   290.836902     2.020398   169.259369     0.101404
# min    10001.000000  1000.000000     1.000000    15.150000     0.000000
# 25%    11250.750000  1253.000000     2.000000   161.895000     0.090000
# 50%    12500.500000  1510.000000     4.000000   309.890000     0.180000
# 75%    13750.250000  1761.000000     6.000000   455.557500     0.270000
# max    15000.000000  1999.000000     7.000000   599.960000     0.350000
#
#        delivery_days  customer_rating      revenue
# count    5000.000000      5000.000000  5000.000000
# mean        6.118800         2.973980  1021.955148
# std         3.153264         1.157722   825.584219
# min         1.000000         1.000000    11.210000
# 25%         3.000000         2.000000   354.527500
# 50%         6.000000         3.000000   796.650000
# 75%         9.000000         4.000000  1515.690000
# max        11.000000         5.000000  4119.330000

# %%
df.shape
# Out:
# (5000, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          5000 non-null   int64
#  1   order_date        5000 non-null   object
#  2   customer_id       5000 non-null   int64
#  3   product_category  5000 non-null   object
#  4   region            5000 non-null   object
#  5   quantity          5000 non-null   int64
#  6   unit_price        5000 non-null   float64
#  7   discount          5000 non-null   float64
#  8   payment_method    5000 non-null   object
#  9   delivery_days     5000 non-null   int64
#  10  customer_rating   5000 non-null   float64
#  11  revenue           5000 non-null   float64
# dtypes: float64(4), int64(4), object(4)
# memory usage: 468.9+ KB

# %%
df.isnull().sum()
# Out:
# order_id            0
# order_date          0
# customer_id         0
# product_category    0
# region              0
# quantity            0
# unit_price          0
# discount            0
# payment_method      0
# delivery_days       0
# customer_rating     0
# revenue             0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4995    False
# 4996    False
# 4997    False
# 4998    False
# 4999    False
# Length: 5000, dtype: bool

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'customer_id', 'product_category', 'region',
#        'quantity', 'unit_price', 'discount', 'payment_method', 'delivery_days',
#        'customer_rating', 'revenue'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['order_id',
#  'order_date',
#  'customer_id',
#  'product_category',
#  'region',
#  'quantity',
#  'unit_price',
#  'discount',
#  'payment_method',
#  'delivery_days',
#  'customer_rating',
#  'revenue']

# %%
df.columns.tolist()
# Out:
# ['order_id',
#  'order_date',
#  'customer_id',
#  'product_category',
#  'region',
#  'quantity',
#  'unit_price',
#  'discount',
#  'payment_method',
#  'delivery_days',
#  'customer_rating',
#  'revenue']

# %%
df[df["revenue"] > 1000]
# Out:
#       order_id order_date  customer_id product_category region  quantity  \
# 0        10001   1/1/2022         1102           Beauty  South         7
# 3        10004   1/4/2022         1270      Electronics   West         5
# 6        10007   1/7/2022         1700         Clothing  South         6
# 7        10008   1/8/2022         1020           Beauty  North         6
# 9        10010  1/10/2022         1121         Clothing   West         4
# ...        ...        ...          ...              ...    ...       ...
# 4980     14981  8/21/2035         1374             Home  North         7
# 4981     14982  8/22/2035         1161           Beauty  North         5
# 4987     14988  8/28/2035         1321      Electronics  South         4
# 4996     14997   9/6/2035         1294           Beauty  North         3
# 4999     15000   9/9/2035         1214             Home   East         7
#
#       unit_price  discount payment_method  delivery_days  customer_rating  \
# 0         373.65      0.28         Wallet             10              4.7
# 3         524.47      0.02         Wallet              6              1.6
# 6         564.60      0.23           Card              1              1.8
# 7         265.71      0.13           Card              2              3.7
# 9         272.71      0.06           Card             10              4.5
# ...          ...       ...            ...            ...              ...
# 4980      525.18      0.10           Card              8              3.6
# 4981      317.25      0.00            COD              7              2.5
# 4987      292.67      0.08           Card              4              2.7
# 4996      553.67      0.14            COD             11              2.2
# 4999      231.58      0.34            COD              5              3.9
#
#       revenue
# 0     1883.20
# 3     2569.90
# 6     2608.45
# 7     1387.01
# 9     1025.39
# ...       ...
# 4980  3308.63
# 4981  1586.25
# 4987  1077.03
# 4996  1428.47
# 4999  1069.90
#
# [2058 rows x 12 columns]

# %%
df[(df["revenue"] > 1000) &(df["quantity"] > 5)]
# Out:
#       order_id order_date  customer_id product_category region  quantity  \
# 0        10001   1/1/2022         1102           Beauty  South         7
# 6        10007   1/7/2022         1700         Clothing  South         6
# 7        10008   1/8/2022         1020           Beauty  North         6
# 10       10011  1/11/2022         1466         Clothing   West         6
# 12       10013  1/13/2022         1330           Beauty  South         7
# ...        ...        ...          ...              ...    ...       ...
# 4974     14975  8/15/2035         1122           Beauty  North         7
# 4975     14976  8/16/2035         1357      Electronics  South         6
# 4976     14977  8/17/2035         1527      Electronics   West         7
# 4980     14981  8/21/2035         1374             Home  North         7
# 4999     15000   9/9/2035         1214             Home   East         7
#
#       unit_price  discount payment_method  delivery_days  customer_rating  \
# 0         373.65      0.28         Wallet             10              4.7
# 6         564.60      0.23           Card              1              1.8
# 7         265.71      0.13           Card              2              3.7
# 10        318.88      0.02            COD              7              1.4
# 12        483.41      0.30            COD              6              1.4
# ...          ...       ...            ...            ...              ...
# 4974      421.15      0.04            COD              3              1.0
# 4975      565.65      0.23           Card              6              1.3
# 4976      381.02      0.10           Card              7              1.2
# 4980      525.18      0.10           Card              8              3.6
# 4999      231.58      0.34            COD              5              3.9
#
#       revenue
# 0     1883.20
# 6     2608.45
# 7     1387.01
# 10    1875.01
# 12    2368.71
# ...       ...
# 4974  2830.13
# 4975  2613.30
# 4976  2400.43
# 4980  3308.63
# 4999  1069.90
#
# [1057 rows x 12 columns]

# %%
df[(df["region"] == "South") |(df["region"] == "West")]
# Out:
#       order_id order_date  customer_id product_category region  quantity  \
# 0        10001   1/1/2022         1102           Beauty  South         7
# 1        10002   1/2/2022         1435         Clothing  South         7
# 3        10004   1/4/2022         1270      Electronics   West         5
# 4        10005   1/5/2022         1106         Clothing   West         5
# 5        10006   1/6/2022         1071      Electronics   West         2
# ...        ...        ...          ...              ...    ...       ...
# 4993     14994   9/3/2035         1926      Electronics   West         1
# 4994     14995   9/4/2035         1507             Home  South         6
# 4995     14996   9/5/2035         1289         Clothing   West         2
# 4997     14998   9/7/2035         1450           Beauty   West         3
# 4998     14999   9/8/2035         1903      Electronics  South         4
#
#       unit_price  discount payment_method  delivery_days  customer_rating  \
# 0         373.65      0.28         Wallet             10              4.7
# 1          47.74      0.09           Card              6              3.9
# 3         524.47      0.02         Wallet              6              1.6
# 4         139.87      0.33         Wallet              4              4.9
# 5         264.44      0.20           Card              3              3.3
# ...          ...       ...            ...            ...              ...
# 4993      113.63      0.14            COD              4              1.0
# 4994       25.85      0.12           Card              5              3.1
# 4995      371.74      0.27            COD              3              2.3
# 4997       77.22      0.24         Wallet              6              3.4
# 4998      138.41      0.21            COD              4              2.8
#
#       revenue
# 0     1883.20
# 1      304.10
# 3     2569.90
# 4      468.56
# 5      423.10
# ...       ...
# 4993    97.72
# 4994   136.49
# 4995   542.74
# 4997   176.06
# 4998   437.38
#
# [2497 rows x 12 columns]

# %%
df.sort_values("revenue")
# Out:
#       order_id  order_date  customer_id product_category region  quantity  \
# 3643     13644  12/23/2031         1435         Clothing  South         1
# 564      10565   7/19/2023         1341         Clothing  North         1
# 70       10071   3/12/2022         1776             Home  South         1
# 4068     14069   2/20/2033         1177         Clothing  South         1
# 376      10377   1/12/2023         1232      Electronics  North         1
# ...        ...         ...          ...              ...    ...       ...
# 3686     13687    2/4/2032         1831         Clothing  North         7
# 3101     13102   6/29/2030         1699           Beauty   East         7
# 2214     12215   1/24/2028         1113      Electronics  South         7
# 4883     14884   5/16/2035         1146      Electronics  South         7
# 809      10810   3/20/2024         1890      Electronics  South         7
#
#       unit_price  discount payment_method  delivery_days  customer_rating  \
# 3643       15.15      0.26           Card              5              3.5
# 564        19.74      0.35            COD              8              4.3
# 70         18.59      0.30           Card              1              1.8
# 4068       19.41      0.32         Wallet              1              1.1
# 376        15.78      0.16         Wallet             10              4.8
# ...          ...       ...            ...            ...              ...
# 3686      578.59      0.03            COD              8              1.6
# 3101      596.12      0.04            COD              6              3.0
# 2214      591.15      0.02         Wallet              1              3.2
# 4883      583.31      0.00           Card              5              4.4
# 809       594.42      0.01           Card              4              4.9
#
#       revenue
# 3643    11.21
# 564     12.83
# 70      13.01
# 4068    13.20
# 376     13.26
# ...       ...
# 3686  3928.63
# 3101  4005.93
# 2214  4055.29
# 4883  4083.17
# 809   4119.33
#
# [5000 rows x 12 columns]

# %%
df.sort_values("revenue", ascending=False)
# Out:
#       order_id  order_date  customer_id product_category region  quantity  \
# 809      10810   3/20/2024         1890      Electronics  South         7
# 4883     14884   5/16/2035         1146      Electronics  South         7
# 2214     12215   1/24/2028         1113      Electronics  South         7
# 3101     13102   6/29/2030         1699           Beauty   East         7
# 3686     13687    2/4/2032         1831         Clothing  North         7
# ...        ...         ...          ...              ...    ...       ...
# 376      10377   1/12/2023         1232      Electronics  North         1
# 4068     14069   2/20/2033         1177         Clothing  South         1
# 70       10071   3/12/2022         1776             Home  South         1
# 564      10565   7/19/2023         1341         Clothing  North         1
# 3643     13644  12/23/2031         1435         Clothing  South         1
#
#       unit_price  discount payment_method  delivery_days  customer_rating  \
# 809       594.42      0.01           Card              4              4.9
# 4883      583.31      0.00           Card              5              4.4
# 2214      591.15      0.02         Wallet              1              3.2
# 3101      596.12      0.04            COD              6              3.0
# 3686      578.59      0.03            COD              8              1.6
# ...          ...       ...            ...            ...              ...
# 376        15.78      0.16         Wallet             10              4.8
# 4068       19.41      0.32         Wallet              1              1.1
# 70         18.59      0.30           Card              1              1.8
# 564        19.74      0.35            COD              8              4.3
# 3643       15.15      0.26           Card              5              3.5
#
#       revenue
# 809   4119.33
# 4883  4083.17
# 2214  4055.29
# 3101  4005.93
# 3686  3928.63
# ...       ...
# 376     13.26
# 4068    13.20
# 70      13.01
# 564     12.83
# 3643    11.21
#
# [5000 rows x 12 columns]

# %%
# Out:
#       order_id order_date  customer_id product_category region  quantity  \
# 0        10001   1/1/2022         1102           Beauty  South         7
# 6        10007   1/7/2022         1700         Clothing  South         6
# 7        10008   1/8/2022         1020           Beauty  North         6
# 10       10011  1/11/2022         1466         Clothing   West         6
# 12       10013  1/13/2022         1330           Beauty  South         7
# ...        ...        ...          ...              ...    ...       ...
# 4974     14975  8/15/2035         1122           Beauty  North         7
# 4975     14976  8/16/2035         1357      Electronics  South         6
# 4976     14977  8/17/2035         1527      Electronics   West         7
# 4980     14981  8/21/2035         1374             Home  North         7
# 4999     15000   9/9/2035         1214             Home   East         7
#
#       unit_price  discount payment_method  delivery_days  customer_rating  \
# 0         373.65      0.28         Wallet             10              4.7
# 6         564.60      0.23           Card              1              1.8
# 7         265.71      0.13           Card              2              3.7
# 10        318.88      0.02            COD              7              1.4
# 12        483.41      0.30            COD              6              1.4
# ...          ...       ...            ...            ...              ...
# 4974      421.15      0.04            COD              3              1.0
# 4975      565.65      0.23           Card              6              1.3
# 4976      381.02      0.10           Card              7              1.2
# 4980      525.18      0.10           Card              8              3.6
# 4999      231.58      0.34            COD              5              3.9
#
#       revenue
# 0     1883.20
# 6     2608.45
# 7     1387.01
# 10    1875.01
# 12    2368.71
# ...       ...
# 4974  2830.13
# 4975  2613.30
# 4976  2400.43
# 4980  3308.63
# 4999  1069.90
#
# [1057 rows x 12 columns]

# %%
# plt.figure(figsize=(10, 5))
plt.plot(df["order_id"], df["revenue"])
plt.xlabel("Order ID")
plt.ylabel("Revenue")
plt.title("Revenue by Order")
plt.show()

# %%
# plt.figure(figsize=(10, 5))
plt.bar(df["product_category"],df["revenue"])
plt.xlabel("Product Category")
plt.ylabel("Revenue")
plt.title("Revenue by Product Category")
plt.show()

# %%
# plt.figure(figsize=(10, 5))
plt.bar(df["product_category"],df["revenue"])
plt.xlabel("Product Category")
plt.ylabel("Revenue")
plt.title("Revenue by Product Category")
plt.grid()
plt.show()

# %%
# plt.figure(figsize=(10, 5))
plt.scatter(df["order_id"],df["revenue"])
plt.xlabel("Order ID")
plt.ylabel("Revenue")
plt.title("Revenue by Order")
plt.show()

# %%
# plt.figure(figsize=(10, 5))
plt.hist(df["revenue"])
plt.xlabel("Revenue")
plt.ylabel("Frequency")
plt.title("Revenue Distribution")
plt.show()

# %%
payment_counts = df["payment_method"].value_counts()
payment_counts
# plt.figure(figsize=(7, 7))
plt.pie(payment_counts.values,labels=payment_counts.index,autopct="%1.1f%%")
plt.title("Payment Method Distribution")
plt.show()
