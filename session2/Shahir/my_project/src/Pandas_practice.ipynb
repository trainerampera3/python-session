# %%
import pandas as pd
df=pd.read_csv('ecommerce_sales_analytics_5000.csv')

# %%
df.head()
# Out:
#    order_id order_date  customer_id product_category region  quantity  \
# 0     10001   1/1/2022         1102           Beauty  South         7
# 1     10002   1/2/2022         1435         Clothing  South         7
# 2     10003   1/3/2022         1860           Beauty   East         3
# 3     10004   1/4/2022         1270      Electronics   West         5
# 4     10005   1/5/2022         1106         Clothing   West         5
#
#    unit_price  discount payment_method  delivery_days  customer_rating  \
# 0      373.65      0.28         Wallet             10              4.7
# 1       47.74      0.09           Card              6              3.9
# 2      311.28      0.31            COD              6              2.5
# 3      524.47      0.02         Wallet              6              1.6
# 4      139.87      0.33         Wallet              4              4.9
#
#    revenue
# 0  1883.20
# 1   304.10
# 2   644.35
# 3  2569.90
# 4   468.56

# %%
series=pd.Series([10,20,30])

# %%
dataframe=pd.DataFrame({'Name':[1,2,3],'Age':[30,20,20]})

# %%
dataframe
# Out:
#    Name  Age
# 0     1   30
# 1     2   20
# 2     3   20

# %%
df.isnull().sum()
# Out:
# order_id            0
# order_date          0
# customer_id         0
# product_category    0
# region              0
# quantity            0
# unit_price          0
# discount            0
# payment_method      0
# delivery_days       0
# customer_rating     0
# revenue             0
# dtype: int64

# %%
import pandas as pd 
data=pd.read_csv('Data.csv')

# %%
data.head()
# Out:
#      Country   Age   Salary Purchased
# 0      India  34.0  92000.0       Yes
# 1  Sri lanka  22.0  25000.0       Yes
# 2      China  31.0  74000.0       Yes
# 3  Sri lanka  29.0      NaN        No
# 4      China  55.0  98000.0       Yes

# %%
data.isnull().sum()
# Out:
# Country      0
# Age          1
# Salary       1
# Purchased    0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Country    15 non-null     object
#  1   Age        14 non-null     float64
#  2   Salary     14 non-null     float64
#  3   Purchased  15 non-null     object
# dtypes: float64(2), object(2)
# memory usage: 608.0+ bytes

# %%
data.iloc[:10,:2]
# Out:
#      Country   Age
# 0      India  34.0
# 1  Sri lanka  22.0
# 2      China  31.0
# 3  Sri lanka  29.0
# 4      China  55.0
# 5      India  24.0
# 6  Sri lanka  28.0
# 7      India   NaN
# 8      China  51.0
# 9      India  44.0

# %%
messy_data=pd.read_csv('crime_incidents_messy.csv')

# %%
messy_data.head()
# Out:
#   incident_id        crime_type     district         city state  \
# 0   INC001115             asslt          Sou    Maplewood    GA
# 1   INC004706          burglary    southeast    Maplewood    OH
# 2   INC002249          Homocide  Southwest       Lakewood    AZ
# 3   INC000021   Property Damage          Cen  Springfield    AZ
# 4   INC000488  Domestc Violence        North     Lakewood    PA
#
#                address    latitude   longitude    incident_datetime  \
# 0      2830 Cedar Lane  170.284100  -77.500710  2024-04-16 08:45:03
# 1         2361 Park Rd   29.422717  -77.167016  2022-01-11 22:03:29
# 2         1067 Main St   39.411460  -98.615298  2022-04-14 11:39:24
# 3  4713 Washington Ave   28.633439  -99.030051  2020-12-09 15:14:24
# 4        1371 River Rd   34.217850 -121.614731  2021-07-24 20:08:13
#
#   officer_id  ... victim_gender  victim_phone  weapon_used severity  \
# 0    OFF0078  ...       Unknown    6223265920      Firearm        2
# ...

# %%
messy_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5250 entries, 0 to 5249
# Data columns (total 33 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   incident_id         5250 non-null   object
#  1   crime_type          5250 non-null   object
#  2   district            5250 non-null   object
#  3   city                5250 non-null   object
#  4   state               5250 non-null   object
#  5   address             5250 non-null   object
#  6   latitude            4992 non-null   float64
#  7   longitude           4961 non-null   float64
#  8   incident_datetime   4910 non-null   object
#  9   officer_id          5250 non-null   object
#  10  officer_first_name  5250 non-null   object
#  11  officer_last_name   5250 non-null   object
#  12  badge_number        4938 non-null   float64
#  13  suspect_id          4440 non-null   object
#  14  suspect_first_name  4440 non-null   object
# ...

# %%
messy_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5250 entries, 0 to 5249
# Data columns (total 33 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   incident_id         5250 non-null   object
#  1   crime_type          5250 non-null   object
#  2   district            5250 non-null   object
#  3   city                5250 non-null   object
#  4   state               5250 non-null   object
#  5   address             5250 non-null   object
#  6   latitude            4992 non-null   float64
#  7   longitude           4961 non-null   float64
#  8   incident_datetime   4910 non-null   object
#  9   officer_id          5250 non-null   object
#  10  officer_first_name  5250 non-null   object
#  11  officer_last_name   5250 non-null   object
#  12  badge_number        4938 non-null   float64
#  13  suspect_id          4440 non-null   object
#  14  suspect_first_name  4440 non-null   object
# ...

# %%
messy_data.describe()
# Out:
#           latitude    longitude  badge_number  suspect_age   victim_age  \
# count  4992.000000  4961.000000   4938.000000  4153.000000  4688.000000
# mean     40.778811   -88.607610   5558.581612    48.418493    52.349403
# std      23.243225    37.214207   2591.581049    43.504819    48.104315
# min      25.002420  -121.975849   1002.000000   -75.000000   -90.000000
# 25%      30.966472  -108.040512   3316.250000    29.000000    27.750000
# 50%      36.967123   -94.656440   5567.000000    46.000000    49.000000
# 75%      43.051502   -80.588056   7862.000000    62.000000    71.000000
# max     199.984200    99.787300   9999.000000   298.000000   298.000000
#
#        num_arrests
# count  4917.000000
# mean      2.262152
# std       1.994556
# min      -5.000000
# 25%       1.000000
# 50%       2.000000
# 75%       4.000000
# max       5.000000

# %%
messy_data.isnull().sum()
# Out:
# incident_id              0
# crime_type               0
# district                 0
# city                     0
# state                    0
# address                  0
# latitude               258
# longitude              289
# incident_datetime      340
# officer_id               0
# officer_first_name       0
# officer_last_name        0
# badge_number           312
# suspect_id             810
# suspect_first_name     810
# suspect_last_name      810
# suspect_age           1097
# suspect_gender        1413
# suspect_race          1601
# victim_id              257
# victim_first_name      257
# victim_last_name       257
# victim_age             562
# victim_gender         1000
# victim_phone          1056
# weapon_used            970
# severity               355
# case_status            731
# resolution             951
# num_arrests            333
# property_loss_usd      436
# reported_online        504
# notes                 1069
# dtype: int64

# %%
messy_data.head()
# Out:
#   incident_id        crime_type     district         city state  \
# 0   INC001115             asslt          Sou    Maplewood    GA
# 1   INC004706          burglary    southeast    Maplewood    OH
# 2   INC002249          Homocide  Southwest       Lakewood    AZ
# 3   INC000021   Property Damage          Cen  Springfield    AZ
# 4   INC000488  Domestc Violence        North     Lakewood    PA
#
#                address    latitude   longitude    incident_datetime  \
# 0      2830 Cedar Lane  170.284100  -77.500710  2024-04-16 08:45:03
# 1         2361 Park Rd   29.422717  -77.167016  2022-01-11 22:03:29
# 2         1067 Main St   39.411460  -98.615298  2022-04-14 11:39:24
# 3  4713 Washington Ave   28.633439  -99.030051  2020-12-09 15:14:24
# 4        1371 River Rd   34.217850 -121.614731  2021-07-24 20:08:13
#
#   officer_id  ... victim_gender  victim_phone  weapon_used severity  \
# 0    OFF0078  ...       Unknown    6223265920      Firearm        2
# ...

# %%
without_null_data=messy_data.dropna()

# %%
without_null_data.isnull().sum()
# Out:
# incident_id           0
# crime_type            0
# district              0
# city                  0
# state                 0
# address               0
# latitude              0
# longitude             0
# incident_datetime     0
# officer_id            0
# officer_first_name    0
# officer_last_name     0
# badge_number          0
# suspect_id            0
# suspect_first_name    0
# suspect_last_name     0
# suspect_age           0
# suspect_gender        0
# suspect_race          0
# victim_id             0
# victim_first_name     0
# victim_last_name      0
# victim_age            0
# victim_gender         0
# victim_phone          0
# weapon_used           0
# severity              0
# case_status           0
# resolution            0
# num_arrests           0
# property_loss_usd     0
# reported_online       0
# notes                 0
# dtype: int64

# %%
without_null_data.duplicated().sum()
# Out:
# 16

# %%
without_null_data.loc[without_null_data.duplicated()==False ,:].duplicated().sum()
# Out:
# 0

# %%
messy_data.duplicated().sum()
# Out:
# 200

# %%
messy_data=messy_data.rename(columns={'crime_type':'type_of_crime'})

# %%
messy_data.head()
# Out:
#   incident_id     type_of_crime     district         city state  \
# 0   INC001115             asslt          Sou    Maplewood    GA
# 1   INC004706          burglary    southeast    Maplewood    OH
# 2   INC002249          Homocide  Southwest       Lakewood    AZ
# 3   INC000021   Property Damage          Cen  Springfield    AZ
# 4   INC000488  Domestc Violence        North     Lakewood    PA
#
#                address    latitude   longitude    incident_datetime  \
# 0      2830 Cedar Lane  170.284100  -77.500710  2024-04-16 08:45:03
# 1         2361 Park Rd   29.422717  -77.167016  2022-01-11 22:03:29
# 2         1067 Main St   39.411460  -98.615298  2022-04-14 11:39:24
# 3  4713 Washington Ave   28.633439  -99.030051  2020-12-09 15:14:24
# 4        1371 River Rd   34.217850 -121.614731  2021-07-24 20:08:13
#
#   officer_id  ... victim_gender  victim_phone  weapon_used severity  \
# 0    OFF0078  ...       Unknown    6223265920      Firearm        2
# ...

# %%
messy_data=messy_data.rename(columns={'type_of_crime':'Crime_type'})

# %%
messy_data.head()
# Out:
#   incident_id        Crime_type     district         city state  \
# 0   INC001115             asslt          Sou    Maplewood    GA
# 1   INC004706          burglary    southeast    Maplewood    OH
# 2   INC002249          Homocide  Southwest       Lakewood    AZ
# 3   INC000021   Property Damage          Cen  Springfield    AZ
# 4   INC000488  Domestc Violence        North     Lakewood    PA
#
#                address    latitude   longitude    incident_datetime  \
# 0      2830 Cedar Lane  170.284100  -77.500710  2024-04-16 08:45:03
# 1         2361 Park Rd   29.422717  -77.167016  2022-01-11 22:03:29
# 2         1067 Main St   39.411460  -98.615298  2022-04-14 11:39:24
# 3  4713 Washington Ave   28.633439  -99.030051  2020-12-09 15:14:24
# 4        1371 River Rd   34.217850 -121.614731  2021-07-24 20:08:13
#
#   officer_id  ... victim_gender  victim_phone  weapon_used severity  \
# 0    OFF0078  ...       Unknown    6223265920      Firearm        2
# ...

# %%
messy_data['latitude']=pd.to_numeric(messy_data['latitude'])

# %%
with_out_null=messy_data.dropna(subset=['latitude'])

# %%
with_out_null['latitude'].isnull().sum()
# Out:
# 0

# %%
with_out_null=with_out_null.astype({'latitude':'int32'})

# %%
with_out_null['latitude']
# Out:
# 0       170
# 1        29
# 2        39
# 3        28
# 4        34
#        ...
# 5245     42
# 5246     38
# 5247     41
# 5248     28
# 5249     30
# Name: latitude, Length: 4992, dtype: int32

# %%
with_out_null=with_out_null.dropna(subset=['longitude'])

# %%
with_out_null=with_out_null.astype({'longitude':'int64'})

# %%
with_out_null['longitude']
# Out:
# 0       -77
# 1       -77
# 2       -98
# 3       -99
# 4      -121
#        ...
# 5245    -79
# 5246   -108
# 5247    -82
# 5248   -111
# 5249    -78
# Name: longitude, Length: 4720, dtype: int64

# %%
with_out_null['notes'].str.upper().str.len()
# Out:
# 0       56.0
# 1       53.0
# 2       53.0
# 3       60.0
# 4        NaN
#         ...
# 5245     NaN
# 5246    57.0
# 5247    57.0
# 5248    54.0
# 5249    57.0
# Name: notes, Length: 4720, dtype: float64

# %%
###Now we will process the data like replacing the null values 
messy_data.describe()
# Out:
#           latitude    longitude  badge_number  suspect_age   victim_age  \
# count  4992.000000  4961.000000   4938.000000  4153.000000  4688.000000
# mean     40.778811   -88.607610   5558.581612    48.418493    52.349403
# std      23.243225    37.214207   2591.581049    43.504819    48.104315
# min      25.002420  -121.975849   1002.000000   -75.000000   -90.000000
# 25%      30.966472  -108.040512   3316.250000    29.000000    27.750000
# 50%      36.967123   -94.656440   5567.000000    46.000000    49.000000
# 75%      43.051502   -80.588056   7862.000000    62.000000    71.000000
# max     199.984200    99.787300   9999.000000   298.000000   298.000000
#
#        num_arrests
# count  4917.000000
# mean      2.262152
# std       1.994556
# min      -5.000000
# 25%       1.000000
# 50%       2.000000
# 75%       4.000000
# max       5.000000

# %%
messy_data.columns
# Out:
# Index(['incident_id', 'Crime_type', 'district', 'city', 'state', 'address',
#        'latitude', 'longitude', 'incident_datetime', 'officer_id',
#        'officer_first_name', 'officer_last_name', 'badge_number', 'suspect_id',
#        'suspect_first_name', 'suspect_last_name', 'suspect_age',
#        'suspect_gender', 'suspect_race', 'victim_id', 'victim_first_name',
#        'victim_last_name', 'victim_age', 'victim_gender', 'victim_phone',
#        'weapon_used', 'severity', 'case_status', 'resolution', 'num_arrests',
#        'property_loss_usd', 'reported_online', 'notes'],
#       dtype='object')

# %%
messy_data.isnull().sum()
# Out:
# incident_id              0
# Crime_type               0
# district                 0
# city                     0
# state                    0
# address                  0
# latitude                 0
# longitude                0
# incident_datetime      340
# officer_id               0
# officer_first_name       0
# officer_last_name        0
# badge_number           312
# suspect_id             810
# suspect_first_name     810
# suspect_last_name      810
# suspect_age           1097
# suspect_gender        1413
# suspect_race          1601
# victim_id              257
# victim_first_name      257
# victim_last_name       257
# victim_age             562
# victim_gender         1000
# victim_phone          1056
# weapon_used            970
# severity               355
# case_status            731
# resolution             951
# num_arrests            333
# property_loss_usd      436
# reported_online        504
# notes                 1069
# dtype: int64

# %%
messy_data['latitude'].hist()
# Out:
# <Axes: >

# %%
messy_data['latitude'].fillna(messy_data['latitude'].mean(),inplace=True)

# %%
messy_data['longitude'].fillna(messy_data['longitude'].mean(),inplace=True)

# %%
messy_data['year']=messy_data['incident_datetime'].str[:10]

# %%
messy_data['time']=messy_data['incident_datetime'].str[11:]

# %%
messy_data.drop('incident_datetime',axis=1,inplace=True)

# %%
messy_data['badge_number'].fillna(messy_data['badge_number'].mean(),inplace=True)

# %%
messy_data.isnull().sum()
# Out:
# incident_id              0
# Crime_type               0
# district                 0
# city                     0
# state                    0
# address                  0
# latitude                 0
# longitude                0
# officer_id               0
# officer_first_name       0
# officer_last_name        0
# badge_number             0
# suspect_id             810
# suspect_first_name     810
# suspect_last_name      810
# suspect_age           1097
# suspect_gender        1413
# suspect_race          1601
# victim_id              257
# victim_first_name      257
# victim_last_name       257
# victim_age             562
# victim_gender         1000
# victim_phone          1056
# weapon_used            970
# severity               355
# case_status            731
# resolution             951
# num_arrests            333
# property_loss_usd      436
# reported_online        504
# notes                 1069
# year                   340
# time                   340
# ...

# %%
messy_data.dropna(subset=['suspect_id'],inplace=True)

# %%
messy_data.isnull().sum()
# Out:
# incident_id             0
# Crime_type              0
# district                0
# city                    0
# state                   0
# address                 0
# latitude                0
# longitude               0
# officer_id              0
# officer_first_name      0
# officer_last_name       0
# badge_number            0
# suspect_id              0
# suspect_first_name      0
# suspect_last_name       0
# suspect_age             0
# suspect_gender        603
# suspect_race          791
# victim_id             214
# victim_first_name     214
# victim_last_name      214
# victim_age            481
# victim_gender         835
# victim_phone          876
# weapon_used           818
# severity              296
# case_status           611
# resolution            769
# num_arrests           267
# property_loss_usd     364
# reported_online       430
# notes                 903
# year                  287
# time                  287
# dtype: int64

# %%
messy_data['suspect_age'].fillna(messy_data['suspect_age'].median(),inplace=True)

# %%
messy_data['suspect_age'].hist()
# Out:
# <Axes: >

# %%
messy_data['suspect_age'].isnull().sum()
# Out:
# 0
